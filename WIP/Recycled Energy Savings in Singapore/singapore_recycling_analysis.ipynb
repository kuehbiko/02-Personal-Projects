# %% [markdown]
# # Annual Energy Savings from Recycled Materials in Singapore

# %% [markdown]
# ## Project Goals
# The goal of this project is to analyze the total garbage collection and recycling rate in Singapore, and to determine the amount of energy saved from recycling.
#
# In this analysis, we will answer questions such as:
# 1. How much energy was saved per year? In which year was this amount the highest? The lowest?
# 2. What is the trend for recycled energy savings in Singapore from 2003 to 2022?
# 3. What is the greatest source of recycled energy savings in 2022 and how has this changed over time?
#
# For more information about how recycling can save energy, please refer here: https://greentumble.com/how-does-recycling-save-energy

# %% [markdown]
# ## Data
# - Recycled energy data for 2003 to 2016 a csv file is taken from the reference for this project, [kingabzpro](https://github.com/kingabzpro/Annual-Recycled-Energy-Saved-in-Singapore/tree/main/Data)
# - Recycled energy data for 2017 to 2021 is taken from the Waste and Recycling Statistics [document](https://www.nea.gov.sg/docs/default-source/default-document-library/waste-and-recycling-statistics-2017-to-2021.pdf) on the NEA website. The data has been extracted to an Excel file.
# - Recycled energy data for 2022 is taken from the [Waste Statistics and Overall Recycling NEA webpage](https://www.nea.gov.sg/our-services/waste-management/waste-statistics-and-overall-recycling)
#
# **Data Dictionary**
#
# |Variable|Description|
# |-----|-----|
#
# - Data for energy conversion is taken from the website [Greentumble](https://greentumble.com/how-does-recycling-save-energy) which has been saved in a csv file.
#
# **Data Dictionary**
#
# |Variable|Description|
# |-----|-----|

# %% [markdown]
# ## Table of Contents
# 1. Data Acquisition
# 2. Data Cleaning and Pre-processing
# 3. Data Exploration and Visualization
# 4. Conclusions

# %% [markdown]
# ***

# %% [markdown]
# ## 1. Data Acquisition

# %% [markdown]
# ### 1.1 Import Libraries

# %%
import pandas as pd
import re
import nltk
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize


import requests
from bs4 import BeautifulSoup

from sqlalchemy import create_engine
import psycopg2
# Out:
# C:\Users\elsf1\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.25.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# ### 1.2 2003-2016: Import Data from `.csv`

# %%
# 2003 - 2016
df_03to16 = pd.read_csv('data/waste-and-recycling-statistics-2003-to-2016.csv')

# %%
df_03to16.head(3)
# Out:
#         waste_type  waste_disposed_of_tonne  total_waste_recycled_tonne  \
# 0             Food                   679900                    111100.0
# 1  Paper/Cardboard                   576000                    607100.0
# 2         Plastics                   762700                     59500.0
#
#    total_waste_generated_tonne  recycling_rate  year
# 0                       791000            0.14  2016
# 1                      1183100            0.51  2016
# 2                       822200            0.07  2016

# %% [markdown]
# ### 1.3 2017-2021: Import Data from `.xlsx`

# %%
# 2017-2021
sheets = ['2017', '2018', '2019', '2020', '2021']

df_17to21_list = []
for sheet in sheets:
    df = pd.read_excel('data/waste-and-recycling-statistics-2017-to-2021.xlsx', sheet_name=sheet)
    df = df.rename(columns=df.iloc[0]).loc[1:]
    df['year'] = sheet
    df_17to21_list.append(df)
    
df_17to21 = pd.concat(df_17to21_list, axis=0)

# %%
df_17to21.head(3)
# Out:
#         Waste Type Total Generated\n('000 tonnes)  \
# 1              C&D                          1,609
# 2    Ferrous metal                          1,379
# 3  Paper/Cardboard                          1,145
#
#   Total Recycled\n('000 tonnes) Recycling Rate Total Disposed\n('000 tonnes)  \
# 1                         1,600            99%                             9
# 2                         1,371            99%                             8
# 3                           569            50%                           576
#
#    year
# 1  2017
# 2  2017
# 3  2017

# %% [markdown]
# ### 1.4 2022: Scrape Data with BeautifulSoup

# %%
#2022
url = 'https://www.nea.gov.sg/our-services/waste-management/waste-statistics-and-overall-recycling'
response = requests.get(url)

if response.status_code == 200:
    soup = BeautifulSoup(response.content, "html.parser")
    table = soup.find('table')
    data = [(cell.text for cell in row.find_all('td')) for row in table.find_all('tr')]

df_22 = pd.DataFrame(data)

# %%
df_22.head(3)
# Out:
#                  0      1      2     3     4
# 0             None   None   None  None  None
# 1    Ferrous metal  1,338  1,331  99%      7
# 2  Paper/Cardboard  1,064    394  37%    671

# %% [markdown]
# ### 1.5 Import Energy Conversion

# %%
energy_saved = pd.read_csv('data/energy_saved.csv')

# %%
energy_saved.head()
# Out:
#   The table gives the amount of energy saved in kilowatt hour (kWh) and the amount of crude oil (barrels) by recycling 1 metric tonne (1000 kilogram)  per waste type  \
# 0    1 barrel oil is approximately 159 litres of oil
# 1                                                NaN
# 2                                           material
# 3                                       energy_saved
# 4                                    crude_oil saved
#
#    Unnamed: 1    Unnamed: 2     Unnamed: 3         Unnamed: 4  Unnamed: 5
# 0         NaN           NaN            NaN                NaN         NaN
# 1         NaN           NaN            NaN                NaN         NaN
# 2     Plastic         Glass  Ferrous Metal  Non-Ferrous Metal       Paper
# 3    5774 Kwh        42 Kwh        642 Kwh          14000 Kwh    4100 kWh
# 4  16 barrels  0.12 barrels    1.8 barrels         40 barrels  11 barrels

# %% [markdown]
# ***

# %% [markdown]
# ## 2. Data Cleaning and Pre-processing

# %% [markdown]
# ### 2.1 Cleaning `df_03to16`

# %%
df_03to16.head(3)
# Out:
#         waste_type  waste_disposed_of_tonne  total_waste_recycled_tonne  \
# 0             Food                   679900                    111100.0
# 1  Paper/Cardboard                   576000                    607100.0
# 2         Plastics                   762700                     59500.0
#
#    total_waste_generated_tonne  recycling_rate  year
# 0                       791000            0.14  2016
# 1                      1183100            0.51  2016
# 2                       822200            0.07  2016

# %%
df_03to16.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 225 entries, 0 to 224
# Data columns (total 6 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   waste_type                   225 non-null    object
#  1   waste_disposed_of_tonne      225 non-null    int64
#  2   total_waste_recycled_tonne   225 non-null    float64
#  3   total_waste_generated_tonne  225 non-null    int64
#  4   recycling_rate               225 non-null    float64
#  5   year                         225 non-null    int64
# dtypes: float64(2), int64(3), object(1)
# memory usage: 10.7+ KB

# %%
# change data types waste_disposed_of_tonne,total_waste_generated_tonne to float
dtype= {'waste_disposed_of_tonne': 'float64', 
        'total_waste_generated_tonne': 'float64'}
df_03to16 = df_03to16.astype(dtype)

# %%
# reoder columns
df_03to16 = df_03to16[['waste_type','total_waste_generated_tonne','total_waste_recycled_tonne','recycling_rate',
                       'waste_disposed_of_tonne','year']]

# %%
# check update
df_03to16.reset_index(drop=True).head(1)
# Out:
#   waste_type  total_waste_generated_tonne  total_waste_recycled_tonne  \
# 0       Food                     791000.0                    111100.0
#
#    recycling_rate  waste_disposed_of_tonne  year
# 0            0.14                 679900.0  2016

# %% [markdown]
# ### 2.2 Cleaning `df_17to22`

# %%
df_17to21.head(3)
# Out:
#         Waste Type Total Generated\n('000 tonnes)  \
# 1              C&D                          1,609
# 2    Ferrous metal                          1,379
# 3  Paper/Cardboard                          1,145
#
#   Total Recycled\n('000 tonnes) Recycling Rate Total Disposed\n('000 tonnes)  \
# 1                         1,600            99%                             9
# 2                         1,371            99%                             8
# 3                           569            50%                           576
#
#    year
# 1  2017
# 2  2017
# 3  2017

# %%
df_17to21.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 75 entries, 1 to 15
# Data columns (total 6 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Waste Type                     75 non-null     object
#  1   Total Generated
# ('000 tonnes)  75 non-null     object
#  2   Total Recycled
# ('000 tonnes)   75 non-null     object
#  3   Recycling Rate                 75 non-null     object
#  4   Total Disposed
# ('000 tonnes)   75 non-null     object
#  5   year                           75 non-null     object
# dtypes: object(6)
# memory usage: 4.1+ KB

# %%
# recursively rename columns
col_list = df_03to16.columns.tolist()
for idx,col in enumerate(col_list):
    df_17to21 = df_17to21.rename(columns={df_17to21.columns[idx]:col})

# %%
df_17to21.head(1)
# Out:
#   waste_type total_waste_generated_tonne total_waste_recycled_tonne  \
# 1        C&D                       1,609                      1,600
#
#   recycling_rate waste_disposed_of_tonne  year
# 1            99%                       9  2017

# %%
# remove special characters from columns (comma, %)
cols = ['total_waste_generated_tonne','total_waste_recycled_tonne','recycling_rate','waste_disposed_of_tonne']
df_17to21[cols] = df_17to21[cols].replace(r'[^\w\s]', '', regex=True)

# %%
# update data types
dtype = {'total_waste_generated_tonne':'float64', 'total_waste_recycled_tonne':'float64', 'waste_disposed_of_tonne':'float64',
        'recycling_rate':'float64'}
df_17to21 = df_17to21.astype(dtype)

# %%
cols = ['total_waste_generated_tonne','total_waste_recycled_tonne','waste_disposed_of_tonne']
df_17to21[cols] = df_17to21[cols] * 1000
df_17to21['recycling_rate'] = df_17to21['recycling_rate'] / 100

# %%
df_17to21.reset_index(drop=True).head(1)
# Out:
#   waste_type  total_waste_generated_tonne  total_waste_recycled_tonne  \
# 0        C&D                    1609000.0                   1600000.0
#
#    recycling_rate  waste_disposed_of_tonne  year
# 0            0.99                   9000.0  2017

# %% [markdown]
# ### 2.3 Cleaning `df_22`

# %%
df_22.head(3)
# Out:
#                  0      1      2     3     4
# 0             None   None   None  None  None
# 1    Ferrous metal  1,338  1,331  99%      7
# 2  Paper/Cardboard  1,064    394  37%    671

# %%
df_22.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       15 non-null     object
#  1   1       15 non-null     object
#  2   2       15 non-null     object
#  3   3       15 non-null     object
#  4   4       15 non-null     object
# dtypes: object(5)
# memory usage: 768.0+ bytes

# %%
df_22['year'] = 2022

# %%
# recursively rename columns
col_list = df_03to16.columns.tolist()
for idx,col in enumerate(col_list):
    df_22 = df_22.rename(columns={df_22.columns[idx]:col})

# %%
df_22.head(2)
# Out:
#       waste_type total_waste_generated_tonne total_waste_recycled_tonne  \
# 0           None                        None                       None
# 1  Ferrous metal                       1,338                      1,331
#
#   recycling_rate waste_disposed_of_tonne  year
# 0           None                    None  2022
# 1           99%                        7  2022

# %%
# drop the first row
df_22 = df_22.loc[1:]

# %%
# remove special characters from columns (comma, %)
cols = ['total_waste_generated_tonne','total_waste_recycled_tonne','recycling_rate','waste_disposed_of_tonne']
df_22[cols] = df_22[cols].replace(r'[^\w\s]', '', regex=True)

# %%
# update data types
dtype = {'total_waste_generated_tonne':'float64', 'total_waste_recycled_tonne':'float64', 'waste_disposed_of_tonne':'float64'}
df_22 = df_22.astype(dtype)
df_22['recycling_rate'] = pd.to_numeric(df_22['recycling_rate'],errors='coerce')

# %%
cols = ['total_waste_generated_tonne','total_waste_recycled_tonne','waste_disposed_of_tonne']
df_22[cols] = df_22[cols] * 1000
df_22['recycling_rate'] = df_22['recycling_rate'] / 100

# %%
df_22.reset_index(drop=True).head(1)
# Out:
#       waste_type  total_waste_generated_tonne  total_waste_recycled_tonne  \
# 0  Ferrous metal                    1338000.0                   1331000.0
#
#    recycling_rate  waste_disposed_of_tonne  year
# 0            0.99                   7000.0  2022

# %% [markdown]
# ### 2.4 Putting it all together

# %%
df0 = pd.concat([df_03to16, df_17to21, df_22]).reset_index(drop=True)

# %%
df0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 315 entries, 0 to 314
# Data columns (total 6 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   waste_type                   315 non-null    object
#  1   total_waste_generated_tonne  315 non-null    float64
#  2   total_waste_recycled_tonne   315 non-null    float64
#  3   recycling_rate               314 non-null    float64
#  4   waste_disposed_of_tonne      315 non-null    float64
#  5   year                         315 non-null    object
# dtypes: float64(4), object(2)
# memory usage: 14.9+ KB

# %%
df0['waste_type'] = df0['waste_type'].str.replace(r'[^A-Za-z0-9\s]+','') \
                                     .apply(lambda x: ' '.join((' '.join(re.findall('[a-zA-Z][^A-Z]*', x))).split())) \
                                     .str.lower()
# Out:
# C:\Users\elsf1\AppData\Local\Temp\ipykernel_9740\1932729354.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df0['waste_type'] = df0['waste_type'].str.replace(r'[^A-Za-z0-9\s]+','') \

# %%
wnl = WordNetLemmatizer()
stop = stopwords.words('English')
df0['waste_type'] = df0['waste_type'].apply(word_tokenize) \
                                     .apply(lambda x: 
                                            ' '.join([str(wnl.lemmatize(word,pos='n')) for word in x if word not in stop]))

# %%
df0['waste_type'].value_counts()
# Out:
# scrap tyre                         21
# plastic                            21
# ferrous metal                      21
# nonferrous metal                   21
# used slag                          21
# glass                              21
# textile leather                    21
# paper cardboard                    21
# horticultural waste                15
# total                              15
# others stone ceramic rubber etc    14
# construction debris                12
# food waste                         11
# sludge                             11
# wood timber                        11
# food                               10
# ash sludge                         10
# wood                               10
# c                                   6
# horticultural                       6
# others stone ceramic etc            6
# overall                             6
# construction demolition c           2
# others                              1
# construction demolition             1
# Name: waste_type, dtype: int64

# %%
df0['waste_type'] = df0['waste_type'].replace('overall','total')
df0.loc[df0['waste_type'].isin(['others','others stone ceramic etc']),'waste_type'] = 'others stone ceramic rubber etc'
df0.loc[df0['waste_type'].isin(['construction demolition','construction demolition c','c']),'waste_type'] = 'construction debris'
df0.loc[df0['waste_type']=='food','waste_type'] = 'food waste'
df0.loc[df0['waste_type']=='wood','waste_type'] ='wood timber'
df0.loc[df0['waste_type']=='sludge','waste_type'] ='ash sludge'
df0.loc[df0['waste_type']=='horticultural','waste_type'] ='horticultural waste'

# %%
df0['waste_type'].value_counts()
# Out:
# food waste                         21
# paper cardboard                    21
# plastic                            21
# construction debris                21
# horticultural waste                21
# wood timber                        21
# ferrous metal                      21
# nonferrous metal                   21
# used slag                          21
# ash sludge                         21
# glass                              21
# textile leather                    21
# scrap tyre                         21
# others stone ceramic rubber etc    21
# total                              21
# Name: waste_type, dtype: int64

# %%
# check duplicates
df0.duplicated().sum()
# Out:
# 0

# %%
# check missing values
df0.isna().sum()
# Out:
# waste_type                     0
# total_waste_generated_tonne    0
# total_waste_recycled_tonne     0
# recycling_rate                 1
# waste_disposed_of_tonne        0
# year                           0
# dtype: int64

# %%
df0[df0['recycling_rate'].isna()]
# Out:
#                           waste_type  total_waste_generated_tonne  \
# 313  others stone ceramic rubber etc                     249000.0
#
#      total_waste_recycled_tonne  recycling_rate  waste_disposed_of_tonne  year
# 313                     30000.0             NaN                 219000.0  2022

# %%
# check the math of recycling rate
df0.loc[313,'recycling_rate'] = round(df0.loc[313,'total_waste_recycled_tonne'] / 
                                      df0.loc[313,'total_waste_generated_tonne'],2)

# %%
df0.isna().sum()
# Out:
# waste_type                     0
# total_waste_generated_tonne    0
# total_waste_recycled_tonne     0
# recycling_rate                 0
# waste_disposed_of_tonne        0
# year                           0
# dtype: int64

# %% [markdown]
# ### 2.5 Cleaning `energy_saved`

# %%
energy_saved.head()
# Out:
#   The table gives the amount of energy saved in kilowatt hour (kWh) and the amount of crude oil (barrels) by recycling 1 metric tonne (1000 kilogram)  per waste type  \
# 0    1 barrel oil is approximately 159 litres of oil
# 1                                                NaN
# 2                                           material
# 3                                       energy_saved
# 4                                    crude_oil saved
#
#    Unnamed: 1    Unnamed: 2     Unnamed: 3         Unnamed: 4  Unnamed: 5
# 0         NaN           NaN            NaN                NaN         NaN
# 1         NaN           NaN            NaN                NaN         NaN
# 2     Plastic         Glass  Ferrous Metal  Non-Ferrous Metal       Paper
# 3    5774 Kwh        42 Kwh        642 Kwh          14000 Kwh    4100 kWh
# 4  16 barrels  0.12 barrels    1.8 barrels         40 barrels  11 barrels

# %%
conversion = energy_saved.T.iloc[1:, 2:] \
                         .reset_index(drop=True) \
                         .rename(columns={2: "material", 
                                          3: "energy_saved_kwh_tonne", 
                                          4: "oil_saved_barrel_tonne"})
conversion
# Out:
#             material energy_saved_kwh_tonne oil_saved_barrel_tonne
# 0            Plastic               5774 Kwh             16 barrels
# 1              Glass                 42 Kwh           0.12 barrels
# 2      Ferrous Metal                642 Kwh            1.8 barrels
# 3  Non-Ferrous Metal              14000 Kwh             40 barrels
# 4              Paper               4100 kWh             11 barrels

# %%
cols = ['energy_saved_kwh_tonne','oil_saved_barrel_tonne']
conversion[cols] = conversion[cols].replace(r'[A-Za-z]*', '', regex=True)

conversion['material'] = conversion['material'].str.replace(r'[^A-Za-z0-9\s]+','').str.lower()
conversion.loc[conversion['material']=='paper', 'material'] = 'paper cardboard'
# Out:
# C:\Users\elsf1\AppData\Local\Temp\ipykernel_9740\2683272866.py:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   conversion['material'] = conversion['material'].str.replace(r'[^A-Za-z0-9\s]+','').str.lower()

# %%
conversion
# Out:
#            material energy_saved_kwh_tonne oil_saved_barrel_tonne
# 0           plastic                  5774                     16
# 1             glass                    42                   0.12
# 2     ferrous metal                   642                    1.8
# 3  nonferrous metal                 14000                     40
# 4   paper cardboard                  4100                     11

# %% [markdown]
# ### 2.6 Load Tables Into PostgreSQL Database

# %%
# %load_ext sql

# %%
try:
    connection = psycopg2.connect(
        user="postgres",
        password="password",
        host="127.0.0.1",
        port="5432",
        database="testdb")
    cursor = connection.cursor()
    print("Connected to the database successfully")
except (Exception, psycopg2.Error) as error:
    print("Error while connecting to PostgreSQL", error)
# Out:
# Connected to the database successfully

# %%
engine = create_engine('postgresql+psycopg2://postgres:password@localhost:5432/testdb')
conn = engine.connect()
df0.to_sql('recycling', con=conn, if_exists='replace', index=False)
conversion.to_sql('conversion', con=conn, if_exists='replace', index=True)
# Out:
# 5

# %%
# connect to database
# %sql postgresql+psycopg2://postgres:password@localhost:5432/testdb
# Out:
# 'Connected: postgres@testdb'

# %%
# %%sql
# -- test connection
#
# SELECT * FROM recycling
# LIMIT 1;
# Out:
#  * postgresql+psycopg2://postgres:***@localhost:5432/testdb
# 1 rows affected.
# [('food waste', 791000.0, 111100.0, 0.14, 679900.0, '2016')]

# %%
# %%sql
# -- test connection
#
# SELECT * FROM conversion
# LIMIT 1;
# Out:
#  * postgresql+psycopg2://postgres:***@localhost:5432/testdb
# 1 rows affected.
# [(0, 'plastic', '5774 ', '16 ')]

# %% [markdown]
# ***

# %% [markdown]
# ## 3. Data Exploration

# %% [markdown]
# References:
# - [CNA 1](https://www.channelnewsasia.com/singapore/big-read-household-recycling-rate-falling-greater-eco-consciousness-waste-goverment-3486066#:~:text=Under%20the%20Zero%20Waste%20Masterplan,capita%20by%2030%20per%20cent)
# - [CNA 2](https://www.channelnewsasia.com/singapore/recycling-rate-waste-generated-statistics-singapore-nea-2022-3460796)
# - [Straits Times](https://www.straitstimes.com/singapore/domestic-recycling-rate-in-singapore-lowest-in-over-a-decade)

# %% [markdown]
# ### 3.1 Summary Stats

# %%
# %%sql
# -- Let's see the most recent recycling statistics
#
# SELECT * FROM recycling
# WHERE year = '2022';
# Out:
#  * postgresql+psycopg2://postgres:***@localhost:5432/testdb
# 15 rows affected.
# [('ferrous metal', 1338000.0, 1331000.0, 0.99, 7000.0, '2022'),
#  ('paper cardboard', 1064000.0, 394000.0, 0.37, 671000.0, '2022'),
#  ('construction debris', 1424000.0, 1419000.0, 0.99, 5000.0, '2022'),
#  ('plastic', 1001000.0, 57000.0, 0.06, 944000.0, '2022'),
#  ('food waste', 813000.0, 146000.0, 0.18, 667000.0, '2022'),
#  ('horticultural waste', 221000.0, 188000.0, 0.85, 32000.0, '2022'),
#  ('wood timber', 419000.0, 298000.0, 0.71, 121000.0, '2022'),
#  ('ash sludge', 241000.0, 27000.0, 0.11, 213000.0, '2022'),
#  ('textile leather', 254000.0, 5000.0, 0.02, 249000.0, '2022'),
#  ('used slag', 169000.0, 166000.0, 0.99, 2000.0, '2022'),
#  ('nonferrous metal', 92000.0, 91000.0, 0.98, 2000.0, '2022'),
#  ('glass', 73000.0, 11000.0, 0.14, 63000.0, '2022'),
#  ('scrap tyre', 26000.0, 25000.0, 0.95, 1000.0, '2022'),
#  ('others stone ceramic rubber etc', 249000.0, 30000.0, 0.12, 219000.0, '2022'),
#  ('total', 7385000.0, 4188000.0, 0.57, 3197000.0, '2022')]

# %%
# %%sql
# -- 3 highest stream of waste material
#
# SELECT
#     waste_type,
#     AVG(total_waste_generated_tonne) AS avg_waste_generated_tonne
# FROM recycling
# WHERE waste_type != 'total'
# GROUP BY waste_type
# ORDER BY 2 DESC
# LIMIT 3;
# Out:
#  * postgresql+psycopg2://postgres:***@localhost:5432/testdb
# 3 rows affected.
# [('paper cardboard', 1174990.4761904762),
#  ('construction debris', 1135871.4285714286),
#  ('ferrous metal', 1132900.0)]

# %% [markdown]
# ### 3.3 Recycling Rate per Year

# %%
# %%sql
# -- recycling rates throughout the years (total only)
#
# SELECT
#     waste_type,
#     recycling_rate,
#     year
# FROM recycling
# WHERE waste_type = 'total'
# ORDER BY year;
# Out:
#  * postgresql+psycopg2://postgres:***@localhost:5432/testdb
# 21 rows affected.
# [('total', 0.47, '2003'),
#  ('total', 0.48, '2004'),
#  ('total', 0.49, '2005'),
#  ('total', 0.51, '2006'),
#  ('total', 0.54, '2007'),
#  ('total', 0.56, '2008'),
#  ('total', 0.57, '2009'),
#  ('total', 0.58, '2010'),
#  ('total', 0.59, '2011'),
#  ('total', 0.6, '2012'),
#  ('total', 0.61, '2013'),
#  ('total', 0.6, '2014'),
#  ('total', 0.61, '2015'),
#  ('total', 0.61, '2016'),
#  ('total', 0.61, '2017'),
#  ('total', 0.61, '2017'),
#  ('total', 0.62, '2018'),
#  ('total', 0.59, '2019'),
#  ('total', 0.52, '2020'),
#  ('total', 0.55, '2021'),
#  ('total', 0.57, '2022')]

# %%
# %%sql
# -- Why is there two rows for 2017?
#
# SELECT * FROM recycling
# WHERE year = '2017';
# Out:
#  * postgresql+psycopg2://postgres:***@localhost:5432/testdb
# 30 rows affected.
# [('construction debris', 1609300.0, 1599900.0, 0.99, 9400.0, '2017'),
#  ('ferrous metal', 1378800.0, 1371000.0, 0.99, 7800.0, '2017'),
#  ('used slag', 272500.0, 269400.0, 0.99, 3100.0, '2017'),
#  ('nonferrous metal', 93700.0, 92200.0, 0.98, 1500.0, '2017'),
#  ('scrap tyre', 35900.0, 33000.0, 0.92, 2900.0, '2017'),
#  ('wood timber', 424100.0, 326800.0, 0.77, 97300.0, '2017'),
#  ('horticultural waste', 328300.0, 220700.0, 0.67, 107600.0, '2017'),
#  ('paper cardboard', 1144800.0, 568800.0, 0.5, 576000.0, '2017'),
#  ('glass', 71300.0, 12400.0, 0.17, 58900.0, '2017'),
#  ('food waste', 809800.0, 133000.0, 0.16, 676800.0, '2017'),
#  ('ash sludge', 243400.0, 28600.0, 0.12, 214800.0, '2017'),
#  ('plastic', 815200.0, 51800.0, 0.06, 763400.0, '2017'),
#  ('textile leather', 150800.0, 9600.0, 0.06, 141200.0, '2017'),
#  ('others stone ceramic rubber etc', 326400.0, 7100.0, 0.02, 319300.0, '2017'),
#  ('total', 7704300.0, 4724300.0, 0.61, 2980000.0, '2017'),
#  ('construction debris', 1609000.0, 1600000.0, 0.99, 9000.0, '2017'),
#  ('ferrous metal', 1379000.0, 1371000.0, 0.99, 8000.0, '2017'),
#  ('paper cardboard', 1145000.0, 569000.0, 0.5, 576000.0, '2017'),
#  ('plastic', 815000.0, 52000.0, 0.06, 763000.0, '2017'),
#  ('food waste', 810000.0, 133000.0, 0.16, 677000.0, '2017'),
#  ('wood timber', 424000.0, 327000.0, 0.77, 97000.0, '2017'),
#  ('horticultural waste', 328000.0, 221000.0, 0.67, 108000.0, '2017'),
#  ('used slag', 273000.0, 269000.0, 0.99, 3000.0, '2017'),
#  ('ash sludge', 243000.0, 29000.0, 0.12, 215000.0, '2017'),
#  ('textile leather', 151000.0, 10000.0, 0.06, 141000.0, '2017'),
#  ('nonferrous metal', 94000.0, 92000.0, 0.98, 2000.0, '2017'),
#  ('glass', 71000.0, 12000.0, 0.17, 59000.0, '2017'),
#  ('scrap tyre', 36000.0, 33000.0, 0.92, 3000.0, '2017'),
#  ('others stone ceramic rubber etc', 326000.0, 7000.0, 0.02, 319000.0, '2017'),
#  ('total', 7704000.0, 4724000.0, 0.61, 2980000.0, '2017')]

# %%
# so what's happening here is that one set of 2017 data was imported with year==2017 as int type 
# and another set was imported with year=='2017' as str type
# so fundamentally they are 2 separate entries and didn't turn up when we checked for duplicates earlier
# turns out df_03to16 actually contains data from 2003 to 2017. this was stated on the reference notebook but i didn't realise
# important lession: read things twice before u import data :")

# %%
# %%sql
# -- let's just go ahead and delete 1 set of 2017 data
#
# DELETE FROM recycling AS r1
# USING recycling AS r2
# WHERE
#     r1.ctid < r2.ctid
#     AND r1.waste_type = r2.waste_type
#     AND r1.year = '2017'
#     AND r2.year = '2017';
# Out:
#  * postgresql+psycopg2://postgres:***@localhost:5432/testdb
# 15 rows affected.
# []

# %%
# %%sql
# -- check that the update was successful
#
# SELECT * FROM recycling
# WHERE year = '2017';
# Out:
#  * postgresql+psycopg2://postgres:***@localhost:5432/testdb
# 15 rows affected.
# [('construction debris', 1609000.0, 1600000.0, 0.99, 9000.0, '2017'),
#  ('ferrous metal', 1379000.0, 1371000.0, 0.99, 8000.0, '2017'),
#  ('paper cardboard', 1145000.0, 569000.0, 0.5, 576000.0, '2017'),
#  ('plastic', 815000.0, 52000.0, 0.06, 763000.0, '2017'),
#  ('food waste', 810000.0, 133000.0, 0.16, 677000.0, '2017'),
#  ('wood timber', 424000.0, 327000.0, 0.77, 97000.0, '2017'),
#  ('horticultural waste', 328000.0, 221000.0, 0.67, 108000.0, '2017'),
#  ('used slag', 273000.0, 269000.0, 0.99, 3000.0, '2017'),
#  ('ash sludge', 243000.0, 29000.0, 0.12, 215000.0, '2017'),
#  ('textile leather', 151000.0, 10000.0, 0.06, 141000.0, '2017'),
#  ('nonferrous metal', 94000.0, 92000.0, 0.98, 2000.0, '2017'),
#  ('glass', 71000.0, 12000.0, 0.17, 59000.0, '2017'),
#  ('scrap tyre', 36000.0, 33000.0, 0.92, 3000.0, '2017'),
#  ('others stone ceramic rubber etc', 326000.0, 7000.0, 0.02, 319000.0, '2017'),
#  ('total', 7704000.0, 4724000.0, 0.61, 2980000.0, '2017')]

# %%
# %%sql
# -- the recycling column is genuinely too limited in the number of significant figures. let's make our own recycling_rate col
#
# SELECT
#     *,
#     ROUND(CAST((total_waste_recycled_tonne/total_waste_generated_tonne) * 100 AS NUMERIC),2) calc_recycling_rate
#  FROM recycling
# LIMIT 5;
# Out:
#  * postgresql+psycopg2://postgres:***@localhost:5432/testdb
# 5 rows affected.
# [('food waste', 791000.0, 111100.0, 0.14, 679900.0, '2016', Decimal('14.05')),
#  ('paper cardboard', 1183100.0, 607100.0, 0.51, 576000.0, '2016', Decimal('51.31')),
#  ('plastic', 822200.0, 59500.0, 0.07, 762700.0, '2016', Decimal('7.24')),
#  ('construction debris', 1595400.0, 1585700.0, 0.99, 9700.0, '2016', Decimal('99.39')),
#  ('horticultural waste', 320500.0, 209000.0, 0.65, 111500.0, '2016', Decimal('65.21'))]

# %%
# finally save to df
# updated recycling rates throughout the years (all materials)
query = pd.read_sql_query(
    '''SELECT *,
           ROUND(CAST((total_waste_recycled_tonne/total_waste_generated_tonne) * 100 AS NUMERIC),2) calc_recycling_rate
       FROM recycling'''
    ,conn)
df = pd.DataFrame(query)
df.to_csv ('output/3-2_updated_recycling_rate.csv', index=False)

# %% [markdown]
# ### 3.3 YOY Changes

# %%
# %%sql
# -- year over year changes in total recycling rate
#
# WITH cte_recycling AS
# (SELECT
#     *,
#     ROUND(CAST((total_waste_recycled_tonne/total_waste_generated_tonne) * 100 AS NUMERIC),2) calc_recycling_rate
#  FROM recycling
# )
#
# SELECT
#     year, waste_type,
#     calc_recycling_rate AS curr_year_rate,
#     LAG(calc_recycling_rate) OVER ( ORDER BY year ) AS prev_year_rate,
#     calc_recycling_rate - LAG(calc_recycling_rate) OVER ( ORDER BY year ) AS yoy_difference
# FROM cte_recycling
# WHERE waste_type = 'total';
# Out:
#  * postgresql+psycopg2://postgres:***@localhost:5432/testdb
# 20 rows affected.
# [('2003', 'total', Decimal('47.02'), None, None),
#  ('2004', 'total', Decimal('48.17'), Decimal('47.02'), Decimal('1.15')),
#  ('2005', 'total', Decimal('49.21'), Decimal('48.17'), Decimal('1.04')),
#  ('2006', 'total', Decimal('50.89'), Decimal('49.21'), Decimal('1.68')),
#  ('2007', 'total', Decimal('54.19'), Decimal('50.89'), Decimal('3.30')),
#  ('2008', 'total', Decimal('55.99'), Decimal('54.19'), Decimal('1.80')),
#  ('2009', 'total', Decimal('57.00'), Decimal('55.99'), Decimal('1.01')),
#  ('2010', 'total', Decimal('57.66'), Decimal('57.00'), Decimal('0.66')),
#  ('2011', 'total', Decimal('58.55'), Decimal('57.66'), Decimal('0.89')),
#  ('2012', 'total', Decimal('59.64'), Decimal('58.55'), Decimal('1.09')),
#  ('2013', 'total', Decimal('61.46'), Decimal('59.64'), Decimal('1.82')),
#  ('2014', 'total', Decimal('59.50'), Decimal('61.46'), Decimal('-1.96')),
#  ('2015', 'total', Decimal('60.59'), Decimal('59.50'), Decimal('1.09')),
#  ('2016', 'total', Decimal('61.03'), Decimal('60.59'), Decimal('0.44')),
#  ('2017', 'total', Decimal('61.32'), Decimal('61.03'), Decimal('0.29')),
#  ('2018', 'total', Decimal('61.73'), Decimal('61.32'), Decimal('0.41')),
#  ('2019', 'total', Decimal('58.99'), Decimal('61.73'), Decimal('-2.74')),
#  ('2020', 'total', Decimal('51.70'), Decimal('58.99'), Decimal('-7.29')),
#  ('2021', 'total', Decimal('55.10'), Decimal('51.70'), Decimal('3.40')),
#  ('2022', 'total', Decimal('56.71'), Decimal('55.10'), Decimal('1.61'))]

# %%
# yoy recycling rates throughout the years (all materials)
query = pd.read_sql_query(
    '''WITH cte_recycling AS 
(SELECT *, ROUND(CAST((total_waste_recycled_tonne/total_waste_generated_tonne) * 100 AS NUMERIC),2) calc_recycling_rate
 FROM recycling)
SELECT year, waste_type, calc_recycling_rate AS curr_year_rate,
    LAG(calc_recycling_rate) OVER ( ORDER BY year ) AS prev_year_rate,
    calc_recycling_rate - LAG(calc_recycling_rate) OVER ( ORDER BY year ) AS yoy_difference
FROM cte_recycling'''
    ,conn)
df = pd.DataFrame(query)
df.to_csv ('output/3-3_yoy_recycling_rate.csv', index=False)

# %%
# %%sql
# -- year over year changes in total waste generated for each material
# WITH cte_recycling AS
# (SELECT
#     *,
#     total_waste_generated_tonne AS curr_year_generated,
#     CASE
#         WHEN year = '2003' THEN NULL
#         ELSE LAG(total_waste_generated_tonne) OVER (ORDER BY waste_type, year)
#     END AS prev_year_generated,
#     CASE
#         WHEN year = '2003' THEN NULL
#         ELSE total_waste_generated_tonne-LAG(total_waste_generated_tonne) OVER (ORDER BY waste_type, year)
#     END AS yoy_difference
# FROM recycling
# ORDER BY waste_type, year)
#
# SELECT
#     year, waste_type, curr_year_generated, prev_year_generated, yoy_difference,
#     ROUND(CAST((yoy_difference/prev_year_generated)*100 AS NUMERIC),2) AS yoy_difference_percent
# FROM cte_recycling;
# Out:
#  * postgresql+psycopg2://postgres:***@localhost:5432/testdb
# 300 rows affected.
# [('2003', 'ash sludge', 88500.0, None, None, None),
#  ('2004', 'ash sludge', 93900.0, 88500.0, 5400.0, Decimal('6.10')),
#  ('2005', 'ash sludge', 98300.0, 93900.0, 4400.0, Decimal('4.69')),
#  ('2006', 'ash sludge', 126800.0, 98300.0, 28500.0, Decimal('28.99')),
#  ('2007', 'ash sludge', 124600.0, 126800.0, -2200.0, Decimal('-1.74')),
#  ('2008', 'ash sludge', 114600.0, 124600.0, -10000.0, Decimal('-8.03')),
#  ('2009', 'ash sludge', 88900.0, 114600.0, -25700.0, Decimal('-22.43')),
#  ('2010', 'ash sludge', 114400.0, 88900.0, 25500.0, Decimal('28.68')),
#  ('2011', 'ash sludge', 152900.0, 114400.0, 38500.0, Decimal('33.65')),
#  ('2012', 'ash sludge', 160200.0, 152900.0, 7300.0, Decimal('4.77')),
#  ('2013', 'ash sludge', 190600.0, 160200.0, 30400.0, Decimal('18.98')),
#  ('2014', 'ash sludge', 148500.0, 190600.0, -42100.0, Decimal('-22.09')),
#  ('2015', 'ash sludge', 196000.0, 148500.0, 47500.0, Decimal('31.99')),
#  ('2016', 'ash sludge', 227300.0, 196000.0, 31300.0, Decimal('15.97')),
#  ('2017', 'ash sludge', 243000.0, 227300.0, 15700.0, Decimal('6.91')),
#  ('2018', 'ash sludge', 240000.0, 243000.0, -3000.0, Decimal('-1.23')),
#  ('2019', 'ash sludge', 252000.0, 240000.0, 12000.0, Decimal('5.00')),
#  ('2020', 'ash sludge', 228000.0, 252000.0, -24000.0, Decimal('-9.52')),
#  ('2021', 'ash sludge', 249000.0, 228000.0, 21000.0, Decimal('9.21')),
#  ('2022', 'ash sludge', 241000.0, 249000.0, -8000.0, Decimal('-3.21')),
#  ('2003', 'construction debris', 422900.0, None, None, None),
#  ('2004', 'construction debris', 509000.0, 422900.0, 86100.0, Decimal('20.36')),
#  ('2005', 'construction debris', 492500.0, 509000.0, -16500.0, Decimal('-3.24')),
#  ('2006', 'construction debris', 619000.0, 492500.0, 126500.0, Decimal('25.69')),
#  ('2007', 'construction debris', 778300.0, 619000.0, 159300.0, Decimal('25.74')),
#  ('2008', 'construction debris', 922000.0, 778300.0, 143700.0, Decimal('18.46')),
#  ('2009', 'construction debris', 1175800.0, 922000.0, 253800.0, Decimal('27.53')),
#  ('2010', 'construction debris', 921800.0, 1175800.0, -254000.0, Decimal('-21.60')),
#  ('2011', 'construction debris', 1203700.0, 921800.0, 281900.0, Decimal('30.58')),
#  ('2012', 'construction debris', 1291800.0, 1203700.0, 88100.0, Decimal('7.32')),
#  ('2013', 'construction debris', 1695300.0, 1291800.0, 403500.0, Decimal('31.24')),
#  ('2014', 'construction debris', 1269700.0, 1695300.0, -425600.0, Decimal('-25.10')),
#  ('2015', 'construction debris', 1411800.0, 1269700.0, 142100.0, Decimal('11.19')),
#  ('2016', 'construction debris', 1595400.0, 1411800.0, 183600.0, Decimal('13.00')),
#  ('2017', 'construction debris', 1609000.0, 1595400.0, 13600.0, Decimal('0.85')),
#  ('2018', 'construction debris', 1624000.0, 1609000.0, 15000.0, Decimal('0.93')),
#  ('2019', 'construction debris', 1440000.0, 1624000.0, -184000.0, Decimal('-11.33')),
#  ('2020', 'construction debris', 825000.0, 1440000.0, -615000.0, Decimal('-42.71')),
#  ('2021', 'construction debris', 1013000.0, 825000.0, 188000.0, Decimal('22.79')),
#  ('2022', 'construction debris', 1424000.0, 1013000.0, 411000.0, Decimal('40.57')),
#  ('2003', 'ferrous metal', 856700.0, None, None, None),
#  ('2004', 'ferrous metal', 720200.0, 856700.0, -136500.0, Decimal('-15.93')),
#  ('2005', 'ferrous metal', 818300.0, 720200.0, 98100.0, Decimal('13.62')),
#  ('2006', 'ferrous metal', 725900.0, 818300.0, -92400.0, Decimal('-11.29')),
#  ('2007', 'ferrous metal', 736500.0, 725900.0, 10600.0, Decimal('1.46')),
#  ('2008', 'ferrous metal', 784800.0, 736500.0, 48300.0, Decimal('6.56')),
#  ('2009', 'ferrous metal', 872000.0, 784800.0, 87200.0, Decimal('11.11')),
#  ('2010', 'ferrous metal', 1194600.0, 872000.0, 322600.0, Decimal('37.00')),
#  ('2011', 'ferrous metal', 1239200.0, 1194600.0, 44600.0, Decimal('3.73')),
#  ('2012', 'ferrous metal', 1386000.0, 1239200.0, 146800.0, Decimal('11.85')),
#  ('2013', 'ferrous metal', 1416000.0, 1386000.0, 30000.0, Decimal('2.16')),
#  ('2014', 'ferrous metal', 1445900.0, 1416000.0, 29900.0, Decimal('2.11')),
#  ('2015', 'ferrous metal', 1348500.0, 1445900.0, -97400.0, Decimal('-6.74')),
#  ('2016', 'ferrous metal', 1357500.0, 1348500.0, 9000.0, Decimal('0.67')),
#  ('2017', 'ferrous metal', 1379000.0, 1357500.0, 21500.0, Decimal('1.58')),
#  ('2018', 'ferrous metal', 1269000.0, 1379000.0, -110000.0, Decimal('-7.98')),
#  ('2019', 'ferrous metal', 1278000.0, 1269000.0, 9000.0, Decimal('0.71')),
#  ('2020', 'ferrous metal', 934000.0, 1278000.0, -344000.0, Decimal('-26.92')),
#  ('2021', 'ferrous metal', 1312000.0, 934000.0, 378000.0, Decimal('40.47')),
#  ('2022', 'ferrous metal', 1338000.0, 1312000.0, 26000.0, Decimal('1.98')),
#  ('2003', 'food waste', 548000.0, None, None, None),
#  ('2004', 'food waste', 531100.0, 548000.0, -16900.0, Decimal('-3.08')),
#  ('2005', 'food waste', 531500.0, 531100.0, 400.0, Decimal('0.08')),
#  ('2006', 'food waste', 542700.0, 531500.0, 11200.0, Decimal('2.11')),
#  ('2007', 'food waste', 558900.0, 542700.0, 16200.0, Decimal('2.99')),
#  ('2008', 'food waste', 568000.0, 558900.0, 9100.0, Decimal('1.63')),
#  ('2009', 'food waste', 606100.0, 568000.0, 38100.0, Decimal('6.71')),
#  ('2010', 'food waste', 640500.0, 606100.0, 34400.0, Decimal('5.68')),
#  ('2011', 'food waste', 675500.0, 640500.0, 35000.0, Decimal('5.46')),
#  ('2012', 'food waste', 703200.0, 675500.0, 27700.0, Decimal('4.10')),
#  ('2013', 'food waste', 796000.0, 703200.0, 92800.0, Decimal('13.20')),
#  ('2014', 'food waste', 788600.0, 796000.0, -7400.0, Decimal('-0.93')),
#  ('2015', 'food waste', 785500.0, 788600.0, -3100.0, Decimal('-0.39')),
#  ('2016', 'food waste', 791000.0, 785500.0, 5500.0, Decimal('0.70')),
#  ('2017', 'food waste', 810000.0, 791000.0, 19000.0, Decimal('2.40')),
#  ('2018', 'food waste', 763000.0, 810000.0, -47000.0, Decimal('-5.80')),
#  ('2019', 'food waste', 744000.0, 763000.0, -19000.0, Decimal('-2.49')),
#  ('2020', 'food waste', 665000.0, 744000.0, -79000.0, Decimal('-10.62')),
#  ('2021', 'food waste', 817000.0, 665000.0, 152000.0, Decimal('22.86')),
#  ('2022', 'food waste', 813000.0, 817000.0, -4000.0, Decimal('-0.49')),
#  ('2003', 'glass', 65500.0, None, None, None),
#  ('2004', 'glass', 73600.0, 65500.0, 8100.0, Decimal('12.37')),
#  ('2005', 'glass', 62600.0, 73600.0, -11000.0, Decimal('-14.95')),
#  ('2006', 'glass', 63000.0, 62600.0, 400.0, Decimal('0.64')),
#  ('2007', 'glass', 65300.0, 63000.0, 2300.0, Decimal('3.65')),
#  ('2008', 'glass', 57100.0, 65300.0, -8200.0, Decimal('-12.56')),
#  ('2009', 'glass', 73100.0, 57100.0, 16000.0, Decimal('28.02')),
#  ('2010', 'glass', 79900.0, 73100.0, 6800.0, Decimal('9.30')),
#  ('2011', 'glass', 72800.0, 79900.0, -7100.0, Decimal('-8.89')),
#  ('2012', 'glass', 74900.0, 72800.0, 2100.0, Decimal('2.88')),
#  ('2013', 'glass', 73500.0, 74900.0, -1400.0, Decimal('-1.87')),
#  ('2014', 'glass', 79500.0, 73500.0, 6000.0, Decimal('8.16')),
#  ('2015', 'glass', 75200.0, 79500.0, -4300.0, Decimal('-5.41')),
#  ('2016', 'glass', 72300.0, 75200.0, -2900.0, Decimal('-3.86')),
#  ('2017', 'glass', 71000.0, 72300.0, -1300.0, Decimal('-1.80')),
#  ('2018', 'glass', 64000.0, 71000.0, -7000.0, Decimal('-9.86')),
#  ('2019', 'glass', 75000.0, 64000.0, 11000.0, Decimal('17.19')),
#  ('2020', 'glass', 66000.0, 75000.0, -9000.0, Decimal('-12.00')),
#  ('2021', 'glass', 74000.0, 66000.0, 8000.0, Decimal('12.12')),
#  ('2022', 'glass', 73000.0, 74000.0, -1000.0, Decimal('-1.35')),
#  ('2003', 'horticultural waste', 304600.0, None, None, None),
#  ('2004', 'horticultural waste', 227000.0, 304600.0, -77600.0, Decimal('-25.48')),
#  ('2005', 'horticultural waste', 199500.0, 227000.0, -27500.0, Decimal('-12.11')),
#  ('2006', 'horticultural waste', 231000.0, 199500.0, 31500.0, Decimal('15.79')),
#  ('2007', 'horticultural waste', 224600.0, 231000.0, -6400.0, Decimal('-2.77')),
#  ('2008', 'horticultural waste', 229300.0, 224600.0, 4700.0, Decimal('2.09')),
#  ('2009', 'horticultural waste', 238100.0, 229300.0, 8800.0, Decimal('3.84')),
#  ('2010', 'horticultural waste', 251000.0, 238100.0, 12900.0, Decimal('5.42')),
#  ('2011', 'horticultural waste', 238800.0, 251000.0, -12200.0, Decimal('-4.86')),
#  ('2012', 'horticultural waste', 247800.0, 238800.0, 9000.0, Decimal('3.77')),
#  ('2013', 'horticultural waste', 252600.0, 247800.0, 4800.0, Decimal('1.94')),
#  ('2014', 'horticultural waste', 278300.0, 252600.0, 25700.0, Decimal('10.17')),
#  ('2015', 'horticultural waste', 362000.0, 278300.0, 83700.0, Decimal('30.08')),
#  ('2016', 'horticultural waste', 320500.0, 362000.0, -41500.0, Decimal('-11.46')),
#  ('2017', 'horticultural waste', 328000.0, 320500.0, 7500.0, Decimal('2.34')),
#  ('2018', 'horticultural waste', 521000.0, 328000.0, 193000.0, Decimal('58.84')),
#  ('2019', 'horticultural waste', 400000.0, 521000.0, -121000.0, Decimal('-23.22')),
#  ('2020', 'horticultural waste', 313000.0, 400000.0, -87000.0, Decimal('-21.75')),
#  ('2021', 'horticultural waste', 332000.0, 313000.0, 19000.0, Decimal('6.07')),
#  ('2022', 'horticultural waste', 221000.0, 332000.0, -111000.0, Decimal('-33.43')),
#  ('2003', 'nonferrous metal', 93900.0, None, None, None),
#  ('2004', 'nonferrous metal', 86900.0, 93900.0, -7000.0, Decimal('-7.45')),
#  ('2005', 'nonferrous metal', 89400.0, 86900.0, 2500.0, Decimal('2.88')),
#  ('2006', 'nonferrous metal', 86700.0, 89400.0, -2700.0, Decimal('-3.02')),
#  ('2007', 'nonferrous metal', 92300.0, 86700.0, 5600.0, Decimal('6.46')),
#  ('2008', 'nonferrous metal', 85000.0, 92300.0, -7300.0, Decimal('-7.91')),
#  ('2009', 'nonferrous metal', 57600.0, 85000.0, -27400.0, Decimal('-32.24')),
#  ('2010', 'nonferrous metal', 85500.0, 57600.0, 27900.0, Decimal('48.44')),
#  ('2011', 'nonferrous metal', 117300.0, 85500.0, 31800.0, Decimal('37.19')),
#  ('2012', 'nonferrous metal', 122500.0, 117300.0, 5200.0, Decimal('4.43')),
#  ('2013', 'nonferrous metal', 135100.0, 122500.0, 12600.0, Decimal('10.29')),
#  ('2014', 'nonferrous metal', 118400.0, 135100.0, -16700.0, Decimal('-12.36')),
#  ('2015', 'nonferrous metal', 180000.0, 118400.0, 61600.0, Decimal('52.03')),
#  ('2016', 'nonferrous metal', 97200.0, 180000.0, -82800.0, Decimal('-46.00')),
#  ('2017', 'nonferrous metal', 94000.0, 97200.0, -3200.0, Decimal('-3.29')),
#  ('2018', 'nonferrous metal', 171000.0, 94000.0, 77000.0, Decimal('81.91')),
#  ('2019', 'nonferrous metal', 126000.0, 171000.0, -45000.0, Decimal('-26.32')),
#  ('2020', 'nonferrous metal', 75000.0, 126000.0, -51000.0, Decimal('-40.48')),
#  ('2021', 'nonferrous metal', 88000.0, 75000.0, 13000.0, Decimal('17.33')),
#  ('2022', 'nonferrous metal', 92000.0, 88000.0, 4000.0, Decimal('4.55')),
#  ('2003', 'others stone ceramic rubber etc', 103800.0, None, None, None),
#  ('2004', 'others stone ceramic rubber etc', 114100.0, 103800.0, 10300.0, Decimal('9.92')),
#  ('2005', 'others stone ceramic rubber etc', 225200.0, 114100.0, 111100.0, Decimal('97.37')),
#  ('2006', 'others stone ceramic rubber etc', 242300.0, 225200.0, 17100.0, Decimal('7.59')),
#  ('2007', 'others stone ceramic rubber etc', 248600.0, 242300.0, 6300.0, Decimal('2.60')),
#  ('2008', 'others stone ceramic rubber etc', 308300.0, 248600.0, 59700.0, Decimal('24.01')),
#  ('2009', 'others stone ceramic rubber etc', 270900.0, 308300.0, -37400.0, Decimal('-12.13')),
#  ('2010', 'others stone ceramic rubber etc', 307400.0, 270900.0, 36500.0, Decimal('13.47')),
#  ('2011', 'others stone ceramic rubber etc', 328400.0, 307400.0, 21000.0, Decimal('6.83')),
#  ('2012', 'others stone ceramic rubber etc', 338400.0, 328400.0, 10000.0, Decimal('3.05')),
#  ('2013', 'others stone ceramic rubber etc', 334800.0, 338400.0, -3600.0, Decimal('-1.06')),
#  ('2014', 'others stone ceramic rubber etc', 360100.0, 334800.0, 25300.0, Decimal('7.56')),
#  ('2015', 'others stone ceramic rubber etc', 365000.0, 360100.0, 4900.0, Decimal('1.36')),
#  ('2016', 'others stone ceramic rubber etc', 382500.0, 365000.0, 17500.0, Decimal('4.79')),
#  ('2017', 'others stone ceramic rubber etc', 326000.0, 382500.0, -56500.0, Decimal('-14.77')),
#  ('2018', 'others stone ceramic rubber etc', 286000.0, 326000.0, -40000.0, Decimal('-12.27')),
#  ('2019', 'others stone ceramic rubber etc', 210000.0, 286000.0, -76000.0, Decimal('-26.57')),
#  ('2020', 'others stone ceramic rubber etc', 193000.0, 210000.0, -17000.0, Decimal('-8.10')),
#  ('2021', 'others stone ceramic rubber etc', 233000.0, 193000.0, 40000.0, Decimal('20.73')),
#  ('2022', 'others stone ceramic rubber etc', 249000.0, 233000.0, 16000.0, Decimal('6.87')),
#  ('2003', 'paper cardboard', 1084700.0, None, None, None),
#  ('2004', 'paper cardboard', 1132100.0, 1084700.0, 47400.0, Decimal('4.37')),
#  ('2005', 'paper cardboard', 1098600.0, 1132100.0, -33500.0, Decimal('-2.96')),
#  ('2006', 'paper cardboard', 1116300.0, 1098600.0, 17700.0, Decimal('1.61')),
#  ('2007', 'paper cardboard', 1202900.0, 1116300.0, 86600.0, Decimal('7.76')),
#  ('2008', 'paper cardboard', 1262500.0, 1202900.0, 59600.0, Decimal('4.95')),
#  ('2009', 'paper cardboard', 1201000.0, 1262500.0, -61500.0, Decimal('-4.87')),
#  ('2010', 'paper cardboard', 1383900.0, 1201000.0, 182900.0, Decimal('15.23')),
#  ('2011', 'paper cardboard', 1368200.0, 1383900.0, -15700.0, Decimal('-1.13')),
#  ('2012', 'paper cardboard', 1252000.0, 1368200.0, -116200.0, Decimal('-8.49')),
#  ('2013', 'paper cardboard', 1261100.0, 1252000.0, 9100.0, Decimal('0.73')),
#  ('2014', 'paper cardboard', 1237400.0, 1261100.0, -23700.0, Decimal('-1.88')),
#  ('2015', 'paper cardboard', 1192200.0, 1237400.0, -45200.0, Decimal('-3.65')),
#  ('2016', 'paper cardboard', 1183100.0, 1192200.0, -9100.0, Decimal('-0.76')),
#  ('2017', 'paper cardboard', 1145000.0, 1183100.0, -38100.0, Decimal('-3.22')),
#  ('2018', 'paper cardboard', 1054000.0, 1145000.0, -91000.0, Decimal('-7.95')),
#  ('2019', 'paper cardboard', 1011000.0, 1054000.0, -43000.0, Decimal('-4.08')),
#  ('2020', 'paper cardboard', 1144000.0, 1011000.0, 133000.0, Decimal('13.16')),
#  ('2021', 'paper cardboard', 1136000.0, 1144000.0, -8000.0, Decimal('-0.70')),
#  ('2022', 'paper cardboard', 1064000.0, 1136000.0, -72000.0, Decimal('-6.34')),
#  ('2003', 'plastic', 579900.0, None, None, None),
#  ('2004', 'plastic', 683100.0, 579900.0, 103200.0, Decimal('17.80')),
#  ('2005', 'plastic', 674800.0, 683100.0, -8300.0, Decimal('-1.22')),
#  ('2006', 'plastic', 656800.0, 674800.0, -18000.0, Decimal('-2.67')),
#  ('2007', 'plastic', 659800.0, 656800.0, 3000.0, Decimal('0.46')),
#  ('2008', 'plastic', 684400.0, 659800.0, 24600.0, Decimal('3.73')),
#  ('2009', 'plastic', 688900.0, 684400.0, 4500.0, Decimal('0.66')),
#  ('2010', 'plastic', 740400.0, 688900.0, 51500.0, Decimal('7.48')),
#  ('2011', 'plastic', 733000.0, 740400.0, -7400.0, Decimal('-1.00')),
#  ('2012', 'plastic', 803400.0, 733000.0, 70400.0, Decimal('9.60')),
#  ('2013', 'plastic', 832200.0, 803400.0, 28800.0, Decimal('3.58')),
#  ('2014', 'plastic', 869000.0, 832200.0, 36800.0, Decimal('4.42')),
#  ('2015', 'plastic', 824600.0, 869000.0, -44400.0, Decimal('-5.11')),
#  ('2016', 'plastic', 822200.0, 824600.0, -2400.0, Decimal('-0.29')),
#  ('2017', 'plastic', 815000.0, 822200.0, -7200.0, Decimal('-0.88')),
#  ('2018', 'plastic', 949000.0, 815000.0, 134000.0, Decimal('16.44')),
#  ('2019', 'plastic', 930000.0, 949000.0, -19000.0, Decimal('-2.00')),
#  ('2020', 'plastic', 868000.0, 930000.0, -62000.0, Decimal('-6.67')),
#  ('2021', 'plastic', 982000.0, 868000.0, 114000.0, Decimal('13.13')),
#  ('2022', 'plastic', 1001000.0, 982000.0, 19000.0, Decimal('1.93')),
#  ('2003', 'scrap tyre', 14400.0, None, None, None),
#  ('2004', 'scrap tyre', 14700.0, 14400.0, 300.0, Decimal('2.08')),
#  ('2005', 'scrap tyre', 16800.0, 14700.0, 2100.0, Decimal('14.29')),
#  ('2006', 'scrap tyre', 23900.0, 16800.0, 7100.0, Decimal('42.26')),
#  ('2007', 'scrap tyre', 25500.0, 23900.0, 1600.0, Decimal('6.69')),
#  ('2008', 'scrap tyre', 25100.0, 25500.0, -400.0, Decimal('-1.57')),
#  ('2009', 'scrap tyre', 22600.0, 25100.0, -2500.0, Decimal('-9.96')),
#  ('2010', 'scrap tyre', 24000.0, 22600.0, 1400.0, Decimal('6.19')),
#  ('2011', 'scrap tyre', 22000.0, 24000.0, -2000.0, Decimal('-8.33')),
#  ('2012', 'scrap tyre', 18400.0, 22000.0, -3600.0, Decimal('-16.36')),
#  ('2013', 'scrap tyre', 21600.0, 18400.0, 3200.0, Decimal('17.39')),
#  ('2014', 'scrap tyre', 26200.0, 21600.0, 4600.0, Decimal('21.30')),
#  ('2015', 'scrap tyre', 35500.0, 26200.0, 9300.0, Decimal('35.50')),
#  ('2016', 'scrap tyre', 32700.0, 35500.0, -2800.0, Decimal('-7.89')),
#  ('2017', 'scrap tyre', 36000.0, 32700.0, 3300.0, Decimal('10.09')),
#  ('2018', 'scrap tyre', 32000.0, 36000.0, -4000.0, Decimal('-11.11')),
#  ('2019', 'scrap tyre', 33000.0, 32000.0, 1000.0, Decimal('3.13')),
#  ('2020', 'scrap tyre', 23000.0, 33000.0, -10000.0, Decimal('-30.30')),
#  ('2021', 'scrap tyre', 27000.0, 23000.0, 4000.0, Decimal('17.39')),
#  ('2022', 'scrap tyre', 26000.0, 27000.0, -1000.0, Decimal('-3.70')),
#  ('2003', 'textile leather', 91600.0, None, None, None),
#  ('2004', 'textile leather', 114500.0, 91600.0, 22900.0, Decimal('25.00')),
#  ('2005', 'textile leather', 89000.0, 114500.0, -25500.0, Decimal('-22.27')),
#  ('2006', 'textile leather', 91800.0, 89000.0, 2800.0, Decimal('3.15')),
#  ('2007', 'textile leather', 110100.0, 91800.0, 18300.0, Decimal('19.93')),
#  ('2008', 'textile leather', 93300.0, 110100.0, -16800.0, Decimal('-15.26')),
#  ('2009', 'textile leather', 109100.0, 93300.0, 15800.0, Decimal('16.93')),
#  ('2010', 'textile leather', 120900.0, 109100.0, 11800.0, Decimal('10.82')),
#  ('2011', 'textile leather', 131000.0, 120900.0, 10100.0, Decimal('8.35')),
#  ('2012', 'textile leather', 159300.0, 131000.0, 28300.0, Decimal('21.60')),
#  ('2013', 'textile leather', 156600.0, 159300.0, -2700.0, Decimal('-1.69')),
#  ('2014', 'textile leather', 158600.0, 156600.0, 2000.0, Decimal('1.28')),
#  ('2015', 'textile leather', 156700.0, 158600.0, -1900.0, Decimal('-1.20')),
#  ('2016', 'textile leather', 150700.0, 156700.0, -6000.0, Decimal('-3.83')),
#  ('2017', 'textile leather', 151000.0, 150700.0, 300.0, Decimal('0.20')),
#  ('2018', 'textile leather', 220000.0, 151000.0, 69000.0, Decimal('45.70')),
#  ('2019', 'textile leather', 168000.0, 220000.0, -52000.0, Decimal('-23.64')),
#  ('2020', 'textile leather', 137000.0, 168000.0, -31000.0, Decimal('-18.45')),
#  ('2021', 'textile leather', 189000.0, 137000.0, 52000.0, Decimal('37.96')),
#  ('2022', 'textile leather', 254000.0, 189000.0, 65000.0, Decimal('34.39')),
#  ('2003', 'total', 4728200.0, None, None, None),
#  ('2004', 'total', 4789700.0, 4728200.0, 61500.0, Decimal('1.30')),
#  ('2005', 'total', 5018200.0, 4789700.0, 228500.0, Decimal('4.77')),
#  ('2006', 'total', 5220500.0, 5018200.0, 202300.0, Decimal('4.03')),
#  ('2007', 'total', 5600800.0, 5220500.0, 380300.0, Decimal('7.28')),
#  ('2008', 'total', 5970200.0, 5600800.0, 369400.0, Decimal('6.60')),
#  ('2009', 'total', 6114100.0, 5970200.0, 143900.0, Decimal('2.41')),
#  ('2010', 'total', 6517000.0, 6114100.0, 402900.0, Decimal('6.59')),
#  ('2011', 'total', 6898300.0, 6517000.0, 381300.0, Decimal('5.85')),
#  ('2012', 'total', 7269500.0, 6898300.0, 371200.0, Decimal('5.38')),
#  ('2013', 'total', 7851500.0, 7269500.0, 582000.0, Decimal('8.01')),
#  ('2014', 'total', 7514500.0, 7851500.0, -337000.0, Decimal('-4.29')),
#  ('2015', 'total', 7673500.0, 7514500.0, 159000.0, Decimal('2.12')),
#  ('2016', 'total', 7814200.0, 7673500.0, 140700.0, Decimal('1.83')),
#  ('2017', 'total', 7704000.0, 7814200.0, -110200.0, Decimal('-1.41')),
#  ('2018', 'total', 7759000.0, 7704000.0, 55000.0, Decimal('0.71')),
#  ('2019', 'total', 7278000.0, 7759000.0, -481000.0, Decimal('-6.20')),
#  ('2020', 'total', 5880000.0, 7278000.0, -1398000.0, Decimal('-19.21')),
#  ('2021', 'total', 6944000.0, 5880000.0, 1064000.0, Decimal('18.10')),
#  ('2022', 'total', 7385000.0, 6944000.0, 441000.0, Decimal('6.35')),
#  ('2003', 'used slag', 260300.0, None, None, None),
#  ('2004', 'used slag', 267200.0, 260300.0, 6900.0, Decimal('2.65')),
#  ('2005', 'used slag', 382400.0, 267200.0, 115200.0, Decimal('43.11')),
#  ('2006', 'used slag', 470600.0, 382400.0, 88200.0, Decimal('23.06')),
#  ('2007', 'used slag', 527200.0, 470600.0, 56600.0, Decimal('12.03')),
#  ('2008', 'used slag', 566200.0, 527200.0, 39000.0, Decimal('7.40')),
#  ('2009', 'used slag', 422400.0, 566200.0, -143800.0, Decimal('-25.40')),
#  ('2010', 'used slag', 382700.0, 422400.0, -39700.0, Decimal('-9.40')),
#  ('2011', 'used slag', 341600.0, 382700.0, -41100.0, Decimal('-10.74')),
#  ('2012', 'used slag', 367800.0, 341600.0, 26200.0, Decimal('7.67')),
#  ('2013', 'used slag', 353700.0, 367800.0, -14100.0, Decimal('-3.83')),
#  ('2014', 'used slag', 366300.0, 353700.0, 12600.0, Decimal('3.56')),
#  ('2015', 'used slag', 369900.0, 366300.0, 3600.0, Decimal('0.98')),
#  ('2016', 'used slag', 251100.0, 369900.0, -118800.0, Decimal('-32.12')),
#  ('2017', 'used slag', 273000.0, 251100.0, 21900.0, Decimal('8.72')),
#  ('2018', 'used slag', 246000.0, 273000.0, -27000.0, Decimal('-9.89')),
#  ('2019', 'used slag', 174000.0, 246000.0, -72000.0, Decimal('-29.27')),
#  ('2020', 'used slag', 106000.0, 174000.0, -68000.0, Decimal('-39.08')),
#  ('2021', 'used slag', 182000.0, 106000.0, 76000.0, Decimal('71.70')),
#  ('2022', 'used slag', 169000.0, 182000.0, -13000.0, Decimal('-7.14')),
#  ('2003', 'wood timber', 213400.0, None, None, None),
#  ('2004', 'wood timber', 222300.0, 213400.0, 8900.0, Decimal('4.17')),
#  ('2005', 'wood timber', 239300.0, 222300.0, 17000.0, Decimal('7.65')),
#  ('2006', 'wood timber', 223700.0, 239300.0, -15600.0, Decimal('-6.52')),
#  ('2007', 'wood timber', 246200.0, 223700.0, 22500.0, Decimal('10.06')),
#  ('2008', 'wood timber', 269600.0, 246200.0, 23400.0, Decimal('9.50')),
#  ('2009', 'wood timber', 287600.0, 269600.0, 18000.0, Decimal('6.68')),
#  ('2010', 'wood timber', 270000.0, 287600.0, -17600.0, Decimal('-6.12')),
#  ('2011', 'wood timber', 273900.0, 270000.0, 3900.0, Decimal('1.44')),
#  ('2012', 'wood timber', 343800.0, 273900.0, 69900.0, Decimal('25.52')),
#  ('2013', 'wood timber', 332400.0, 343800.0, -11400.0, Decimal('-3.32')),
#  ('2014', 'wood timber', 367900.0, 332400.0, 35500.0, Decimal('10.68')),
#  ('2015', 'wood timber', 370600.0, 367900.0, 2700.0, Decimal('0.73')),
#  ('2016', 'wood timber', 530700.0, 370600.0, 160100.0, Decimal('43.20')),
#  ('2017', 'wood timber', 424000.0, 530700.0, -106700.0, Decimal('-20.11')),
#  ('2018', 'wood timber', 320000.0, 424000.0, -104000.0, Decimal('-24.53')),
#  ('2019', 'wood timber', 438000.0, 320000.0, 118000.0, Decimal('36.88')),
#  ('2020', 'wood timber', 304000.0, 438000.0, -134000.0, Decimal('-30.59')),
#  ('2021', 'wood timber', 310000.0, 304000.0, 6000.0, Decimal('1.97')),
#  ('2022', 'wood timber', 419000.0, 310000.0, 109000.0, Decimal('35.16'))]

# %%
# yoy waste generated throughout the years (total)
query = pd.read_sql_query(
    '''WITH cte_recycling AS
(SELECT *, total_waste_generated_tonne AS curr_year_generated,
    CASE
        WHEN year = '2003' THEN NULL
        ELSE LAG(total_waste_generated_tonne) OVER (ORDER BY waste_type, year) 
    END AS prev_year_generated,
    CASE
        WHEN year = '2003' THEN NULL
        ELSE total_waste_generated_tonne-LAG(total_waste_generated_tonne) OVER (ORDER BY waste_type, year)
    END AS yoy_difference
FROM recycling
ORDER BY waste_type, year)
SELECT
    year, waste_type, curr_year_generated, prev_year_generated, yoy_difference,
    ROUND(CAST((yoy_difference/prev_year_generated)*100 AS NUMERIC),2) AS yoy_difference_percent
FROM cte_recycling'''
    ,conn)
df = pd.DataFrame(query)
df.to_csv ('output/3-3_yoy_total_waste_generated.csv', index=False)

# %% [markdown]
# ### 3.4 Energy Conversions

# %%
# %%sql
# -- take a look a the conversion table
#
# SELECT * FROM conversion;
# Out:
#  * postgresql+psycopg2://postgres:***@localhost:5432/testdb
# 5 rows affected.
# [(0, 'plastic', '5774 ', '16 '),
#  (1, 'glass', '42 ', '0.12 '),
#  (2, 'ferrous metal', '642 ', '1.8 '),
#  (3, 'nonferrous metal', '14000 ', '40 '),
#  (4, 'paper cardboard', '4100 ', '11 ')]

# %%
# %%sql
# -- let's join tables to see how much energy we have saved for these materials
#
# SELECT
#     r.year,
#     SUM(r.total_waste_recycled_tonne) AS total_waste_recycled_tonne,
#     SUM(CAST(c.energy_saved_kwh_tonne AS numeric) * CAST(r.total_waste_recycled_tonne AS numeric)) AS total_energy_saved_kwh,
#     SUM(CAST(c.oil_saved_barrel_tonne AS numeric) * CAST(r.total_waste_recycled_tonne AS numeric)) AS total_oil_saved_barrels
# FROM recycling AS r
# RIGHT JOIN conversion AS c
#     ON r.waste_type = c.material
# GROUP BY r.year
# ORDER BY year;
# Out:
#  * postgresql+psycopg2://postgres:***@localhost:5432/testdb
# 20 rows affected.
# [('2003', 1386300.0, Decimal('3711601800'), Decimal('10224744.00')),
#  ('2004', 1320600.0, Decimal('3982085000'), Decimal('10946908.00')),
#  ('2005', 1454100.0, Decimal('4239495800'), Decimal('11658336.00')),
#  ('2006', 1383700.0, Decimal('4204076800'), Decimal('11542288.00')),
#  ('2007', 1443400.0, Decimal('4458449600'), Decimal('12236096.00')),
#  ('2008', 1486800.0, Decimal('4328918800'), Decimal('11878000.00')),
#  ('2009', 1503800.0, Decimal('3885627800'), Decimal('10634032.00')),
#  ('2010', 2036100.0, Decimal('5225630800'), Decimal('14325604.00')),
#  ('2011', 2137800.0, Decimal('5773364000'), Decimal('15870448.00')),
#  ('2012', 2226800.0, Decimal('5548164800'), Decimal('15267800.00')),
#  ('2013', 2268300.0, Decimal('5787191000'), Decimal('15957312.00')),
#  ('2014', 2225800.0, Decimal('5330703200'), Decimal('14681404.00')),
#  ('2015', 2169800.0, Decimal('5911099000'), Decimal('16383192.00')),
#  ('2016', 2128700.0, Decimal('5043543400'), Decimal('13900564.00')),
#  ('2017', 2096000.0, Decimal('4801834000'), Decimal('13240240.00')),
#  ('2018', 2069000.0, Decimal('5828758000'), Decimal('16171440.00')),
#  ('2019', 1891000.0, Decimal('4606340000'), Decimal('12778320.00')),
#  ('2020', 1478000.0, Decimal('3598418000'), Decimal('9922840.00')),
#  ('2021', 1897000.0, Decimal('4183422000'), Decimal('11566880.00')),
#  ('2022', 1884000.0, Decimal('4073482000'), Decimal('11283120.00'))]

# %%
# energy conversions
query = pd.read_sql_query(
    '''SELECT 
    *,
    CAST(c.energy_saved_kwh_tonne AS numeric) * CAST(r.total_waste_recycled_tonne AS numeric) AS total_energy_saved_kwh,
    CAST(c.oil_saved_barrel_tonne AS numeric) * CAST(r.total_waste_recycled_tonne AS numeric) AS total_oil_saved_barrels
FROM recycling AS r
RIGHT JOIN conversion AS c
    ON r.waste_type = c.material
ORDER BY year'''
    ,conn)
df = pd.DataFrame(query)
df.to_csv ('output/3-4_energy_conversions.csv', index=False)

# %% [markdown]
# ***

# %% [markdown]
# ## 4. Conclusions

# %% [markdown]
# ***
